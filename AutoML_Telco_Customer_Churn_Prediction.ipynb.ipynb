# %% [markdown]
# # Aim:
# To predict customer churn using Automated Machine Learning (AutoML) techniques on the Telco Customer Churn dataset, and explore model selection and performance evaluation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# !pip install h2o
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.8/265.8 MB 2.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for h2o: filename=h2o-3.46.0.6-py2.py3-none-any.whl size=265859786 sha256=b0566b0107b18dc762d5229c3b5c78239da05d0a27f37207b0d9118dd17432f1
#   Stored in directory: /root/.cache/pip/wheels/0c/95/eb/b449c73f478dbc4557b80170cf7f2aa6db15862877e9a63536
# Successfully built h2o
# ...

# %%
import h2o
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321..... not found.
# Attempting to start a local H2O server...
#   Java Version: openjdk version "11.0.25" 2024-10-15; OpenJDK Runtime Environment (build 11.0.25+9-post-Ubuntu-1ubuntu122.04); OpenJDK 64-Bit Server VM (build 11.0.25+9-post-Ubuntu-1ubuntu122.04, mixed mode, sharing)
#   Starting server from /usr/local/lib/python3.10/dist-packages/h2o/backend/bin/h2o.jar
#   Ice root: /tmp/tmpqlau_fd7
#   JVM stdout: /tmp/tmpqlau_fd7/h2o_unknownUser_started_from_python.out
#   JVM stderr: /tmp/tmpqlau_fd7/h2o_unknownUser_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  -----------------------------------------------------------------------------------------
# H2O_cluster_uptime:         03 secs
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# ...

# %%
train_df = h2o.H2OFrame(df)
train_df.describe()
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# Rows:7043
# Cols:21
#          customerID    gender    SeniorCitizen       Partner    Dependents    tenure              PhoneService    MultipleLines     InternetService    OnlineSecurity    OnlineBackup    DeviceProtection    TechSupport    StreamingTV    StreamingMovies    Contract        PaperlessBilling    PaymentMethod              MonthlyCharges     TotalCharges        Churn
# -------  ------------  --------  ------------------  ---------  ------------  ------------------  --------------  ----------------  -----------------  ----------------  --------------  ------------------  -------------  -------------  -----------------  --------------  ------------------  -------------------------  -----------------  ------------------  -------
# ...

# %%
test = pd.read_csv('/content/WA_Fn-UseC_-Telco-Customer-Churn.csv')
test = h2o.H2OFrame(test)

x = test.columns
y = 'Churn'
x.remove(y)
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%

# %%
from h2o.automl import H2OAutoML
aml = H2OAutoML(max_runtime_secs=600,
                seed=1,
                balance_classes=False,
                project_name="Project_1")
aml.train(x=x, y=y, training_frame=train_df)
# Out:
# AutoML progress: |
# 09:38:51.854: _train param, Dropping bad and constant columns: [customerID]
# 09:39:01.623: _train param, Dropping bad and constant columns: [customerID]
# 09:39:07.281: _train param, Dropping bad and constant columns: [customerID]
# 09:39:19.398: _train param, Dropping unused columns: [customerID]
# 09:39:20.243: _train param, Dropping bad and constant columns: [customerID]
# 09:39:26.684: _train param, Dropping bad and constant columns: [customerID]
# 09:39:45.576: _train param, Dropping bad and constant columns: [customerID]
# 09:39:50.684: _train param, Dropping bad and constant columns: [customerID]
# 09:39:57.209: _train param, Dropping bad and constant columns: [customerID]
# 09:40:04.188: _train param, Dropping unused columns: [customerID]
# 09:40:05.510: _train param, Dropping unused columns: [customerID]
# 09:40:06.614: _train param, Dropping bad and constant columns: [customerID]
# ...
